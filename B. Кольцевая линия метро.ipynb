# %% [markdown]
# ![B.%20%D0%9A%D0%BE%D0%BB%D1%8C%D1%86%D0%B5%D0%B2%D0%B0%D1%8F%20%D0%BB%D0%B8%D0%BD%D0%B8%D1%8F%20%D0%BC%D0%B5%D1%82%D1%80%D0%BE.png](attachment:B.%20%D0%9A%D0%BE%D0%BB%D1%8C%D1%86%D0%B5%D0%B2%D0%B0%D1%8F%20%D0%BB%D0%B8%D0%BD%D0%B8%D1%8F%20%D0%BC%D0%B5%D1%82%D1%80%D0%BE.png)

# %%
n, i, j = map(int, input().split())

if i < j:
    a = n-j-1+i
    b = j-i-1
    if a < b:
        min = a
    else:
        min = b


if i > j:
    a = n-i-1+j
    b = i-j-1
    if a < b:
        min = a
    else:
        min = b

print(min)
