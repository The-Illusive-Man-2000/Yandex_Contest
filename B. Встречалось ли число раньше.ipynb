# %% [markdown]
# ![B.%20%D0%92%D1%81%D1%82%D1%80%D0%B5%D1%87%D0%B0%D0%BB%D0%BE%D1%81%D1%8C%20%D0%BB%D0%B8%20%D1%87%D0%B8%D1%81%D0%BB%D0%BE%20%D1%80%D0%B0%D0%BD%D1%8C%D1%88%D0%B5.png](attachment:B.%20%D0%92%D1%81%D1%82%D1%80%D0%B5%D1%87%D0%B0%D0%BB%D0%BE%D1%81%D1%8C%20%D0%BB%D0%B8%20%D1%87%D0%B8%D1%81%D0%BB%D0%BE%20%D1%80%D0%B0%D0%BD%D1%8C%D1%88%D0%B5.png)

# %%
spisok = list(map(int, input().split()))

m = set()

for i in spisok:
    if i in m:
        print('YES')
    else:
        print('NO')
        m.add(i)
