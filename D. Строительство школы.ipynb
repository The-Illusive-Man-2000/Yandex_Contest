# %% [markdown]
# ![D.%20%D0%A1%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D1%81%D1%82%D0%B2%D0%BE%20%D1%88%D0%BA%D0%BE%D0%BB%D1%8B.png](attachment:D.%20%D0%A1%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D1%81%D1%82%D0%B2%D0%BE%20%D1%88%D0%BA%D0%BE%D0%BB%D1%8B.png)

# %%
N = int(input())
l = list(map(int, input().split()))

if N % 2 != 0:
    result = l[(N//2)]

else:
    result = l[int(N/2)]

print(result)
