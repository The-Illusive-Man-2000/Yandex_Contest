# %% [markdown]
# ![E.%20%D0%94%D0%B8%D0%BF%D0%BB%D0%BE%D0%BC%D1%8B%20%D0%B2%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0%D1%85.png](attachment:E.%20%D0%94%D0%B8%D0%BF%D0%BB%D0%BE%D0%BC%D1%8B%20%D0%B2%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0%D1%85.png)

# %%
N = int(input())
diplopms = list(map(int, input().split()))

max = 0
for i in range(N):
    if diplopms[i] >= max:
        max = diplopms[i]

diplopms.remove(max)

sum = 0
for i in range(N-1):
    sum = sum + diplopms[i]



print(sum)
