# %% [markdown]
# ![A.%20%D0%9A%D0%BE%D0%BB%D0%B8%D1%87%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D1%81%D0%BE%D0%B2%D0%BF%D0%B0%D0%B4%D0%B0%D1%8E%D1%89%D0%B8%D1%85.png](attachment:A.%20%D0%9A%D0%BE%D0%BB%D0%B8%D1%87%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D1%81%D0%BE%D0%B2%D0%BF%D0%B0%D0%B4%D0%B0%D1%8E%D1%89%D0%B8%D1%85.png)

# %%
spisok1 = list(map(int, input().split()))
spisok2 = list(map(int, input().split()))
spisok3 = set(spisok2)

s = 0
for i in range(len(spisok1)):
    if spisok1[i] in spisok3:
        s +=1

print(s)
